# %%
import geopandas as gpd

# read the blood lead data
blood_lead_shp = 'child_blood_lead_levels_by_ct.shp'
blood_lead_gdf = gpd.read_file(blood_lead_shp)

# print the first 5 records 
blood_lead_gdf.head()
# Out:
#     census_tra  data_redac  num_bll_5p  num_screen  perc_5plus  \
# 0  42101000100           0         0.0       100.0         0.0
# 1  42101000200           1         NaN       109.0         NaN
# 2  42101000300           1         NaN       110.0         NaN
# 3  42101000401           1         NaN        61.0         NaN
# 4  42101000402           0         0.0        41.0         0.0
#
#                                             geometry
# 0  POLYGON ((-75.14147213273969 39.9517072267047,...
# 1  POLYGON ((-75.162377698504 39.9576545523082, -...
# 2  POLYGON ((-75.17820482839041 39.9598134132842,...
# 3  POLYGON ((-75.1729917788024 39.9546437050483, ...
# 4  POLYGON ((-75.1633313650233 39.9533392100125, ...

# %%
# print min value for each neighborhood
print(blood_lead_gdf['perc_5plus'].min()) 
# print the max value
print('The mas value is:', blood_lead_gdf['perc_5plus'].max()) 
#print the mean value of all neighborhoods
print('The mean value is:', blood_lead_gdf['perc_5plus'].mean()) 
# a general discription of the blood lead for all neighborhoods
print(blood_lead_gdf['perc_5plus'].describe())
# Out:
# 0.0
# The mas value is: 17.6
# The mean value is: 5.858661417322836
# count    254.000000
# mean       5.858661
# std        3.939310
# min        0.000000
# 25%        3.225000
# 50%        5.700000
# 75%        8.475000
# max       17.600000
# Name: perc_5plus, dtype: float64

# %%
blood_lead_gdf
# Out:
#       census_tra  data_redac  num_bll_5p  num_screen  perc_5plus  \
# 0    42101000100           0         0.0       100.0         0.0
# 1    42101000200           1         NaN       109.0         NaN
# 2    42101000300           1         NaN       110.0         NaN
# 3    42101000401           1         NaN        61.0         NaN
# 4    42101000402           0         0.0        41.0         0.0
# ..           ...         ...         ...         ...         ...
# 375  42101980200           1         NaN         NaN         NaN
# 376  42101980700           1         NaN         NaN         NaN
# 377  42101980800           1         NaN         NaN         NaN
# 378  42101980900           1         NaN         NaN         NaN
# 379  42101989100           1         NaN         NaN         NaN
#
#                                               geometry
# 0    POLYGON ((-75.14147213273969 39.9517072267047,...
# 1    POLYGON ((-75.162377698504 39.9576545523082, -...
# 2    POLYGON ((-75.17820482839041 39.9598134132842,...
# 3    POLYGON ((-75.1729917788024 39.9546437050483, ...
# 4    POLYGON ((-75.1633313650233 39.9533392100125, ...
# ..                                                 ...
# 375  POLYGON ((-75.05635673803801 40.0876645665025,...
# 376  POLYGON ((-75.1351492487008 39.9286294339812, ...
# 377  POLYGON ((-75.25592702256429 39.9781297321056,...
# 378  POLYGON ((-75.2016453002315 39.937568298222, -...
# 379  POLYGON ((-74.99255713701911 40.035771800404, ...
#
# [380 rows x 6 columns]

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib import cm


fig, ax = plt.subplots(1, figsize=(8, 8))

# read the blood lead data
blood_lead_shp = 'child_blood_lead_levels_by_ct.shp'
blood_lead_gdf = gpd.read_file(blood_lead_shp)

# get the color bar, the string for color can be found here, https://matplotlib.org/3.1.1/gallery/color/colormap_reference.html
cmap = plt.cm.get_cmap('YlGnBu', 6)

# plot the choropleth map of blood lead in Philadelphia
blood_lead_gdf.plot(column='perc_5plus', 
                         cmap='YlGnBu', 
                         edgecolor='0.5',
                         ax = ax,
                         linewidth=0.5,
                         scheme='equal_interval') # 'equal_interval', 'quantiles', 'fisher_jenks', 'fisher_jenks_sampled'
# create a color bar for the map
norm = Normalize(vmin=blood_lead_gdf['perc_5plus'].min(), vmax=blood_lead_gdf['perc_5plus'].max())
n_cmap = cm.ScalarMappable(norm=norm, cmap=cmap)
# n_cmap.set_array([])
cbar = ax.get_figure().colorbar(n_cmap, orientation='horizontal', fraction=0.02, pad=0.0, shrink=0.5)
cbar.ax.set_xlabel('Blood level')

ax.set_axis_off()
plt.axis('equal')
plt.show()
# Out:
# C:\Users\tuh42842\AppData\Local\Continuum\anaconda3\lib\site-packages\mapclassify\classifiers.py:276: RuntimeWarning: invalid value encountered in greater
#   binIds += (x > l) * (x <= r) * k
# C:\Users\tuh42842\AppData\Local\Continuum\anaconda3\lib\site-packages\mapclassify\classifiers.py:276: RuntimeWarning: invalid value encountered in less_equal
#   binIds += (x > l) * (x <= r) * k
# C:\Users\tuh42842\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\function_base.py:3405: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
